# %% [markdown]
# <a href="https://colab.research.google.com/github/jelaenas/DSC1105/blob/main/CESISTA%2C_KJ_GROUP_10_LAB_FA1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
library(ggplot2)
library(readr)

# Direct link to the diamonds CSV
url <- "https://raw.githubusercontent.com/tidyverse/ggplot2/master/data-raw/diamonds.csv"
diamonds_data <- read_csv(url)

# Quick check to ensure it loaded
head(diamonds_data)

# %%
library(ggplot2)

# 1. Create a histogram using the diamonds dataset.
ggplot(diamonds) + geom_histogram(aes(x = carat))

# Re-write this plot using the layer() function instead of geom_histogram(), as demonstrated in class.
# Hint: If you are unsure about default values (e.g., stat, position), inspect the plot object using p$layers.
ggplot(diamonds) +
  layer(
    mapping = aes(x = carat),
    stat = "bin",
    geom = "bar",
    position = "stack"
  )

# 2. Recall that a histogram is a plot that uses stat_bin rather than stat_identity.
# Modify your histogram from Question 1 so that it uses a different geom,
# such as geom_line() or geom_point(), while still relying on stat_bin

ggplot(diamonds) +
  layer(
    mapping = aes(x = carat),
    stat = "bin",
    geom = "line",    # Change to line
    position = "identity"
  )


# 3. Using the histogram with bars from Question 1, add an aesthetic mapping
# based on one of the factor variables in the dataset (e.g., cut, color, or clarity).
# Apply this mapping to either the fill or color aesthetic.

ggplot(diamonds) + geom_histogram(aes(x = carat, fill = cut))

# 4. What is the default position adjustment used in a histogram?
# Change the position adjustment in the histogram you created in Question 3 to a
# different option (hint: try "dodge"), and observe how the plot changes.

ggplot(diamonds) + geom_histogram(aes(x = carat, fill = cut), position = "dodge")
# Out:
# `stat_bin()` using `bins = 30`. Pick better value `binwidth`.
# `stat_bin()` using `bins = 30`. Pick better value `binwidth`.
# plot without title
# `stat_bin()` using `bins = 30`. Pick better value `binwidth`.
# plot without title
# `stat_bin()` using `bins = 30`. Pick better value `binwidth`.
# plot without title
# `stat_bin()` using `bins = 30`. Pick better value `binwidth`.
# plot without title
# `stat_bin()` using `bins = 30`. Pick better value `binwidth`.
# plot without title
# plot without title

# %% [markdown]
# **What is the default position adjustment used in a histogram?**
#
# The default position of the histogram is stacked. After using the dodged position, the cut categories are placed side by side instead of being stacked on one another.
#
# **Reflection**
# In doing this activty, I learned that histograms in ggplot2 are consturcted by uisng the stat_bin and layer functions. The part of the activit that was most challenging was where I had to use the layer function, as I am used to simply using geom_histogram so it was abit more difficult to use the layer funtion. But it did help my understanding on how histograms are constructed. Further, changing the fill to cut and position to dodged, help me understand the data further as it shows how the data is distributed across the different cut categories.
